# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)

# %%
import cv2
from google.colab.patches import cv2_imshow
image = cv2.imread('/content/photocar.png')
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1582x828>

# %%
if image is None:
  print('Error al cargar la imagen')
else:
  width,height = 240,240
  res_image  = cv2.resize(image,(width,height))
  cv2_imshow(res_image)
# Out:
# <PIL.Image.Image image mode=RGB size=240x240>

# %%
grey_img = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(grey_img)
# Out:
# <PIL.Image.Image image mode=L size=1582x828>

# %%
hsv_image = cv2.cvtColor(image,cv2.COLOR_BGR2HSV)
cv2_imshow(hsv_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1582x828>

# %%
grey_img = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(grey_img,100,850)
cv2_imshow(grey_img)
# Out:
# <PIL.Image.Image image mode=L size=1582x828>
